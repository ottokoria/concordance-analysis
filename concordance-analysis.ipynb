# %% [markdown]
# <h4>Appendix One:</h4>

# %%
#TODO: FILTER ONLY CHINESE CHARACTERS
#TODO: WORD COUNT OF KEY HEARING/LISTENING VERBS

# %%
#Python code used in this work

#importing prerequisities 
import os
import string
import re

#opening all ".txt" files from directory for analysis
for path, dirs, files in os.walk("CBETA-texts/ahanbu"): #replace back to ahanbu
    for f in files:
        fileName = os.path.join(path, f)
        with open(fileName, "r") as myFile:
            myFile = myFile.read()
            
#list of unwanted punctuation marks and stop words
stopWords = ['\n','：', '，', '。', '「', '；', '、','」','『','』','！','？'] #these contain handpicked Chinese punctuation
latinStr = string.printable #for all latin letters and common punctuation
for x in latinStr:
    stopWords.append(x)

# %%
#counting all characters
charList = []

for c in myFile:
    if c not in stopWords:
        charList.append(c)

charDict = {}

for c in charList:
    charDict[c] = charDict.get(c, 0)+1

#sorting from highest value
charDictSorted = sorted(charDict.items(), key=lambda x: x[1], reverse=True)    

charDictSorted
# Out:
# [('諸', 1716),
#  ('有', 1305),
#  ('彼', 1281),
#  ('其', 1002),
#  ('如', 974),
#  ('是', 942),
#  ('王', 893),
#  ('天', 845),
#  ('中', 799),
#  ('等', 766),
#  ('比', 756),
#  ('丘', 746),
#  ('生', 691),
#  ('於', 675),
#  ('時', 669),
#  ('種', 646),
#  ('羅', 646),
#  ('已', 589),
#  ('所', 579),
#  ('大', 576),
#  ('一', 572),
#  ('者', 533),
#  ('復', 494),
#  ('為', 493),
#  ('不', 481),
#  ('地', 444),
#  ('眾', 432),
#  ('之', 410),
#  ('以', 403),
#  ('無', 401),
#  ('至', 395),
#  ('七', 394),
#  ('三', 393),
#  ('作', 389),
#  ('此', 372),
#  ('人', 369),
#  ('名', 367),
#  ('四', 361),
#  ('故', 360),
#  ('獄', 355),
#  ('多', 354),
#  ('乃', 354),
#  ('而', 343),
#  ('身', 342),
#  ('行', 340),
#  ('阿', 339),
#  ('二', 337),
#  ('亦', 334),
#  ('十', 331),
#  ('及', 324),
#  ('善', 322),
#  ('各', 319),
#  ('出', 316),
#  ('摩', 314),
#  ('世', 312),
#  ('處', 312),
#  ('次', 311),
#  ('若', 304),
#  ('住', 301),
#  ('上', 299),
#  ('迦', 287),
#  ('言', 287),
#  ('修', 280),
#  ('即', 280),
#  ('我', 271),
#  ('自', 267),
#  ('輩', 266),
#  ('間', 266),
#  ('寶', 260),
#  ('五', 258),
#  ('受', 257),
#  ('色', 245),
#  ('那', 244),
#  ('陀', 239),
#  ('門', 238),
#  ('千', 236),
#  ('樹', 228),
#  ('說', 227),
#  ('見', 227),
#  ('廣', 220),
#  ('由', 217),
#  ('百', 216),
#  ('何', 214),
#  ('宮', 206),
#  ('向', 205),
#  ('轉', 204),
#  ('重', 202),
#  ('皆', 199),
#  ('山', 199),
#  ('旬', 199),
#  ('輪', 199),
#  ('或', 199),
#  ('然', 197),
#  ('可', 195),
#  ('因', 191),
#  ('成', 190),
#  ('相', 189),
#  ('婆', 185),
#  ('緣', 180),
#  ('來', 179),
#  ('殿', 179),
#  ('日', 178),
#  ('下', 176),
#  ('水', 174),
#  ('樂', 168),
#  ('沙', 167),
#  ('欲', 167),
#  ('命', 166),
#  ('當', 165),
#  ('小', 165),
#  ('得', 165),
#  ('闍', 163),
#  ('第', 161),
#  ('囉', 161),
#  ('提', 155),
#  ('六', 155),
#  ('前', 151),
#  ('踰', 148),
#  ('光', 147),
#  ('爾', 145),
#  ('業', 144),
#  ('龍', 143),
#  ('心', 142),
#  ('華', 141),
#  ('惡', 140),
#  ('又', 139),
#  ('汝', 138),
#  ('具', 138),
#  ('最', 137),
#  ('非', 137),
#  ('洲', 136),
#  ('金', 136),
#  ('花', 136),
#  ('嚴', 135),
#  ('苦', 135),
#  ('入', 134),
#  ('在', 132),
#  ('利', 132),
#  ('毘', 130),
#  ('取', 130),
#  ('知', 129),
#  ('子', 128),
#  ('林', 127),
#  ('雜', 127),
#  ('從', 126),
#  ('道', 125),
#  ('念', 124),
#  ('化', 123),
#  ('燒', 123),
#  ('悉', 122),
#  ('法', 122),
#  ('頭', 122),
#  ('象', 122),
#  ('既', 118),
#  ('長', 117),
#  ('未', 117),
#  ('切', 117),
#  ('餘', 116),
#  ('須', 115),
#  ('縱', 115),
#  ('足', 114),
#  ('閻', 113),
#  ('食', 113),
#  ('邊', 113),
#  ('量', 112),
#  ('後', 109),
#  ('月', 109),
#  ('面', 108),
#  ('意', 108),
#  ('留', 107),
#  ('勝', 107),
#  ('經', 106),
#  ('車', 106),
#  ('風', 105),
#  ('果', 104),
#  ('八', 103),
#  ('方', 103),
#  ('馬', 102),
#  ('帝', 101),
#  ('略', 100),
#  ('起', 99),
#  ('共', 99),
#  ('便', 99),
#  ('今', 98),
#  ('鳥', 98),
#  ('現', 98),
#  ('分', 97),
#  ('高', 97),
#  ('園', 97),
#  ('熱', 97),
#  ('浮', 95),
#  ('界', 95),
#  ('萬', 95),
#  ('正', 95),
#  ('聚', 93),
#  ('謂', 91),
#  ('波', 91),
#  ('火', 91),
#  ('白', 90),
#  ('池', 90),
#  ('明', 90),
#  ('求', 90),
#  ('鐵', 90),
#  ('究', 89),
#  ('形', 89),
#  ('極', 88),
#  ('隨', 87),
#  ('虛', 87),
#  ('口', 86),
#  ('海', 85),
#  ('壞', 85),
#  ('香', 84),
#  ('常', 83),
#  ('應', 83),
#  ('城', 82),
#  ('能', 82),
#  ('夜', 82),
#  ('梨', 82),
#  ('終', 81),
#  ('還', 79),
#  ('惱', 79),
#  ('淨', 78),
#  ('持', 78),
#  ('觀', 78),
#  ('瑙', 78),
#  ('釋', 78),
#  ('覆', 78),
#  ('到', 77),
#  ('走', 77),
#  ('合', 76),
#  ('實', 76),
#  ('妙', 75),
#  ('吒', 75),
#  ('周', 74),
#  ('黑', 74),
#  ('破', 74),
#  ('也', 73),
#  ('牆', 73),
#  ('熾', 73),
#  ('壽', 73),
#  ('盡', 72),
#  ('雲', 72),
#  ('俱', 71),
#  ('他', 70),
#  ('吹', 70),
#  ('離', 70),
#  ('守', 70),
#  ('彌', 69),
#  ('欝', 69),
#  ('木', 69),
#  ('圍', 69),
#  ('鉢', 69),
#  ('焰', 69),
#  ('年', 69),
#  ('空', 67),
#  ('喜', 67),
#  ('置', 67),
#  ('更', 66),
#  ('往', 66),
#  ('苑', 64),
#  ('東', 64),
#  ('質', 64),
#  ('雨', 64),
#  ('安', 63),
#  ('別', 63),
#  ('詣', 62),
#  ('去', 62),
#  ('翅', 61),
#  ('力', 61),
#  ('猶', 61),
#  ('觸', 61),
#  ('衣', 61),
#  ('事', 60),
#  ('梵', 60),
#  ('尼', 59),
#  ('遍', 59),
#  ('歡', 59),
#  ('著', 59),
#  ('手', 58),
#  ('北', 58),
#  ('女', 58),
#  ('流', 58),
#  ('令', 58),
#  ('散', 57),
#  ('則', 57),
#  ('奢', 57),
#  ('報', 57),
#  ('舍', 56),
#  ('微', 56),
#  ('曰', 56),
#  ('河', 56),
#  ('垣', 56),
#  ('耶', 55),
#  ('遶', 55),
#  ('半', 55),
#  ('西', 55),
#  ('與', 55),
#  ('譬', 55),
#  ('就', 54),
#  ('巨', 54),
#  ('葉', 54),
#  ('妄', 54),
#  ('難', 54),
#  ('德', 53),
#  ('主', 53),
#  ('匝', 53),
#  ('南', 53),
#  ('遊', 53),
#  ('本', 52),
#  ('集', 51),
#  ('告', 51),
#  ('遠', 51),
#  ('神', 51),
#  ('莊', 51),
#  ('滅', 51),
#  ('護', 51),
#  ('云', 50),
#  ('唯', 50),
#  ('熏', 50),
#  ('音', 50),
#  ('優', 50),
#  ('兩', 50),
#  ('劫', 50),
#  ('造', 50),
#  ('味', 49),
#  ('依', 48),
#  ('并', 48),
#  ('拘', 48),
#  ('鞞', 48),
#  ('戒', 48),
#  ('滿', 47),
#  ('墮', 47),
#  ('昔', 47),
#  ('聞', 46),
#  ('茶', 46),
#  ('夫', 46),
#  ('隋', 45),
#  ('語', 45),
#  ('銀', 45),
#  ('鳴', 45),
#  ('伽', 44),
#  ('戲', 44),
#  ('稱', 44),
#  ('內', 44),
#  ('愛', 44),
#  ('干', 44),
#  ('死', 43),
#  ('奔', 43),
#  ('普', 43),
#  ('用', 43),
#  ('治', 43),
#  ('少', 42),
#  ('和', 42),
#  ('擲', 42),
#  ('盧', 42),
#  ('開', 42),
#  ('忍', 42),
#  ('鬪', 42),
#  ('清', 41),
#  ('照', 41),
#  ('赤', 41),
#  ('割', 41),
#  ('達', 40),
#  ('甚', 40),
#  ('聖', 40),
#  ('欄', 40),
#  ('青', 40),
#  ('承', 40),
#  ('猛', 40),
#  ('楯', 39),
#  ('枝', 39),
#  ('牟', 39),
#  ('屬', 39),
#  ('瓔', 39),
#  ('器', 39),
#  ('將', 39),
#  ('丈', 39),
#  ('憙', 38),
#  ('樓', 38),
#  ('揵', 38),
#  ('珞', 38),
#  ('熟', 38),
#  ('外', 37),
#  ('立', 37),
#  ('細', 37),
#  ('兵', 37),
#  ('教', 37),
#  ('氣', 36),
#  ('聲', 36),
#  ('訶', 36),
#  ('乘', 36),
#  ('會', 36),
#  ('使', 36),
#  ('答', 36),
#  ('居', 35),
#  ('叉', 35),
#  ('軟', 35),
#  ('體', 35),
#  ('初', 35),
#  ('ā', 35),
#  ('瞿', 34),
#  ('圓', 34),
#  ('好', 34),
#  ('皮', 34),
#  ('肉', 34),
#  ('同', 33),
#  ('思', 33),
#  ('根', 33),
#  ('頗', 33),
#  ('師', 33),
#  ('璃', 32),
#  ('節', 32),
#  ('叫', 32),
#  ('喚', 32),
#  ('偈', 32),
#  ('放', 32),
#  ('睺', 32),
#  ('願', 31),
#  ('漸', 31),
#  ('真', 31),
#  ('並', 31),
#  ('柔', 31),
#  ('骨', 31),
#  ('岸', 31),
#  ('調', 31),
#  ('脚', 31),
#  ('寒', 31),
#  ('藏', 31),
#  ('煮', 31),
#  ('致', 31),
#  ('過', 30),
#  ('降', 30),
#  ('珠', 30),
#  ('娑', 30),
#  ('飛', 30),
#  ('逸', 30),
#  ('智', 30),
#  ('呼', 30),
#  ('孫', 30),
#  ('麤', 29),
#  ('識', 29),
#  ('沸', 29),
#  ('戰', 29),
#  ('坐', 28),
#  ('尊', 28),
#  ('畏', 28),
#  ('琉', 28),
#  ('壁', 28),
#  ('網', 28),
#  ('櫓', 28),
#  ('冷', 28),
#  ('眷', 28),
#  ('浴', 28),
#  ('疾', 28),
#  ('脫', 28),
#  ('飲', 28),
#  ('岐', 28),
#  ('通', 27),
#  ('益', 27),
#  ('邪', 27),
#  ('裂', 27),
#  ('久', 27),
#  ('仁', 27),
#  ('堂', 26),
#  ('禪', 26),
#  ('端', 26),
#  ('捨', 26),
#  ('兜', 26),
#  ('鈴', 26),
#  ('魔', 26),
#  ('烏', 26),
#  ('甘', 26),
#  ('恒', 26),
#  ('類', 26),
#  ('舉', 26),
#  ('功', 26),
#  ('瞋', 26),
#  ('耳', 25),
#  ('率', 25),
#  ('斫', 25),
#  ('草', 25),
#  ('快', 25),
#  ('右', 25),
#  ('活', 25),
#  ('磨', 25),
#  ('刀', 25),
#  ('繩', 25),
#  ('婁', 25),
#  ('國', 24),
#  ('威', 24),
#  ('鬘', 24),
#  ('搔', 24),
#  ('除', 24),
#  ('臥', 24),
#  ('隣', 24),
#  ('盛', 24),
#  ('末', 24),
#  ('血', 24),
#  ('沫', 24),
#  ('盲', 24),
#  ('仗', 24),
#  ('災', 24),
#  ('弗', 23),
#  ('賢', 23),
#  ('却', 23),
#  ('石', 23),
#  ('異', 23),
#  ('沒', 23),
#  ('澡', 23),
#  ('施', 23),
#  ('殺', 23),
#  ('歲', 23),
#  ('脂', 23),
#  ('老', 22),
#  ('佛', 22),
#  ('汁', 22),
#  ('乾', 22),
#  ('洗', 22),
#  ('釜', 22),
#  ('伏', 22),
#  ('福', 22),
#  ('胎', 22),
#  ('支', 22),
#  ('電', 22),
#  ('解', 22),
#  ('癡', 22),
#  ('卵', 22),
#  ('卷', 21),
#  ('飯', 21),
#  ('曾', 21),
#  ('家', 21),
#  ('頂', 21),
#  ('垂', 21),
#  ('布', 21),
#  ('耨', 21),
#  ('澤', 21),
#  ('鼻', 21),
#  ('落', 21),
#  ('減', 21),
#  ('增', 21),
#  ('踊', 21),
#  ('躍', 21),
#  ('救', 21),
#  ('馳', 21),
#  ('愚', 21),
#  ('父', 20),
#  ('敵', 20),
#  ('牛', 20),
#  ('佉', 20),
#  ('民', 20),
#  ('供', 20),
#  ('順', 20),
#  ('母', 20),
#  ('養', 20),
#  ('備', 20),
#  ('消', 20),
#  ('灰', 20),
#  ('打', 20),
#  ('品', 19),
#  ('論', 19),
#  ('平', 19),
#  ('九', 19),
#  ('物', 19),
#  ('濁', 19),
#  ('怖', 19),
#  ('奉', 19),
#  ('舊', 19),
#  ('齋', 19),
#  ('斷', 19),
#  ('數', 19),
#  ('歸', 19),
#  ('逼', 19),
#  ('責', 19),
#  ('譯', 18),
#  ('問', 18),
#  ('飾', 18),
#  ('倍', 18),
#  ('穢', 18),
#  ('低', 18),
#  ('指', 18),
#  ('速', 18),
#  ('動', 18),
#  ('勅', 18),
#  ('銅', 18),
#  ('筋', 18),
#  ('髓', 18),
#  ('濕', 18),
#  ('義', 17),
#  ('殊', 17),
#  ('閣', 17),
#  ('臺', 17),
#  ('想', 17),
#  ('涼', 17),
#  ('米', 17),
#  ('飢', 17),
#  ('臣', 17),
#  ('罪', 17),
#  ('撲', 17),
#  ('土', 16),
#  ('剎', 16),
#  ('直', 16),
#  ('輦', 16),
#  ('伊', 16),
#  ('男', 16),
#  ('美', 16),
#  ('揩', 16),
#  ('度', 16),
#  ('趣', 16),
#  ('服', 16),
#  ('病', 16),
#  ('氷', 16),
#  ('亂', 16),
#  ('被', 16),
#  ('障', 16),
#  ('郭', 16),
#  ('ṭ', 16),
#  ('泥', 15),
#  ('鷄', 15),
#  ('恐', 15),
#  ('訖', 15),
#  ('財', 15),
#  ('膝', 15),
#  ('敬', 15),
#  ('蘇', 15),
#  ('仰', 15),
#  ('段', 15),
#  ('閃', 15),
#  ('免', 15),
#  ('勒', 14),
#  ('蜜', 14),
#  ('但', 14),
#  ('繫', 14),
#  ('旃', 14),
#  ('粳', 14),
#  ('舌', 14),
#  ('察', 14),
#  ('先', 14),
#  ('覺', 14),
#  ('腹', 14),
#  ('膿', 14),
#  ('示', 14),
#  ('罵', 14),
#  ('左', 14),
#  ('殘', 14),
#  ('議', 13),
#  ('姓', 13),
#  ('檀', 13),
#  ('目', 13),
#  ('甜', 13),
#  ('乳', 13),
#  ('牙', 13),
#  ('純', 13),
#  ('曼', 13),
#  ('坒', 13),
#  ('膩', 13),
#  ('變', 13),
#  ('停', 13),
#  ('眼', 13),
#  ('洞', 13),
#  ('慧', 13),
#  ('習', 13),
#  ('慈', 13),
#  ('截', 13),
#  ('腸', 13),
#  ('害', 13),
#  ('斤', 13),
#  ('塵', 13),
#  ('諍', 13),
#  ('縛', 13),
#  ('箭', 13),
#  ('笈', 12),
#  ('座', 12),
#  ('斯', 12),
#  ('諦', 12),
#  ('髮', 12),
#  ('牢', 12),
#  ('呵', 12),
#  ('軸', 12),
#  ('擎', 12),
#  ('毛', 12),
#  ('息', 12),
#  ('悅', 12),
#  ('酥', 12),
#  ('資', 12),
#  ('婦', 12),
#  ('勿', 12),
#  ('歷', 12),
#  ('倒', 12),
#  ('遂', 12),
#  ('刺', 12),
#  ('毀', 12),
#  ('弓', 12),
#  ('杖', 12),
#  ('賴', 12),
#  ('羯', 12),
#  ('惟', 12),
#  ('記', 12),
#  ('竺', 11),
#  ('窟', 11),
#  ('信', 11),
#  ('止', 11),
#  ('挍', 11),
#  ('輕', 11),
#  ('獸', 11),
#  ('失', 11),
#  ('滑', 11),
#  ('迴', 11),
#  ('宿', 11),
#  ('字', 11),
#  ('莫', 11),
#  ('渴', 11),
#  ('逐', 11),
#  ('貪', 11),
#  ('銜', 11),
#  ('肘', 11),
#  ('隱', 11),
#  ('馭', 11),
#  ('歎', 11),
#  ('燋', 11),
#  ('烟', 11),
#  ('室', 11),
#  ('脣', 11),
#  ('痛', 11),
#  ('捉', 11),
#  ('忽', 11),
#  ('壯', 11),
#  ('晝', 11),
#  ('患', 11),
#  ('憶', 11),
#  ('徹', 10),
#  ('厚', 10),
#  ('雅', 10),
#  ('文', 10),
#  ('瞻', 10),
#  ('錯', 10),
#  ('湧', 10),
#  ('黃', 10),
#  ('藕', 10),
#  ('蓋', 10),
#  ('潤', 10),
#  ('潔', 10),
#  ('夭', 10),
#  ('玉', 10),
#  ('逋', 10),
#  ('擣', 10),
#  ('堪', 10),
#  ('短', 10),
#  ('臾', 10),
#  ('屋', 10),
#  ('咽', 10),
#  ('竪', 10),
#  ('研', 10),
#  ('赫', 10),
#  ('必', 10),
#  ('怨', 10),
#  ('發', 10),
#  ('讚', 10),
#  ('扇', 10),
#  ('鵄', 10),
#  ('鵂', 10),
#  ('騎', 10),
#  ('影', 10),
#  ('嫁', 10),
#  ('退', 10),
#  ('仙', 10),
#  ('定', 9),
#  ('默', 9),
#  ('深', 9),
#  ('傍', 9),
#  ('似', 9),
#  ('充', 9),
#  ('纖', 9),
#  ('導', 9),
#  ('噉', 9),
#  ('易', 9),
#  ('船', 9),
#  ('巧', 9),
#  ('誰', 9),
#  ('啟', 9),
#  ('陸', 9),
#  ('收', 9),
#  ('穀', 9),
#  ('村', 9),
#  ('厭', 9),
#  ('斛', 9),
#  ('喉', 9),
#  ('垢', 9),
#  ('柯', 9),
#  ('登', 9),
#  ('證', 9),
#  ('寂', 9),
#  ('群', 9),
#  ('迷', 9),
#  ('續', 9),
#  ('孝', 9),
#  ('含', 9),
#  ('稻', 9),
#  ('領', 8),
#  ('連', 8),
#  ('曲', 8),
#  ('峯', 8),
#  ('房', 8),
#  ('齊', 8),
#  ('曇', 8),
#  ('雞', 8),
#  ('塼', 8),
#  ('蟲', 8),
#  ('博', 8),
#  ('劣', 8),
#  ('娛', 8),
#  ('騰', 8),
#  ('吉', 8),
#  ('灌', 8),
#  ('密', 8),
#  ('懸', 8),
#  ('耕', 8),
#  ('交', 8),
#  ('步', 8),
#  ('塗', 8),
#  ('盜', 8),
#  ('駕', 8),
#  ('釘', 8),
#  ('暫', 8),
#  ('宅', 8),
#  ('鑽', 8),
#  ('卒', 8),
#  ('橫', 8),
#  ('損', 8),
#  ('壓', 8),
#  ('遣', 8),
#  ('乏', 8),
#  ('拼', 8),
#  ('鋸', 8),
#  ('凡', 8),
#  ('恚', 8),
#  ('頞', 8),
#  ('唱', 8),
#  ('計', 8),
#  ('反', 8),
#  ('僧', 8),
#  ('豈', 8),
#  ('悲', 8),
#  ('槃', 8),
#  ('遮', 8),
#  ('頻', 8),
#  ('助', 8),
#  ('顛', 8),
#  ('占', 8),
#  ('竭', 8),
#  ('再', 8),
#  ('鹹', 8),
#  ('闕', 8),
#  ('晡', 7),
#  ('底', 7),
#  ('固', 7),
#  ('級', 7),
#  ('際', 7),
#  ('蛇', 7),
#  ('板', 7),
#  ('柱', 7),
#  ('栴', 7),
#  ('執', 7),
#  ('畜', 7),
#  ('糞', 7),
#  ('繞', 7),
#  ('肥', 7),
#  ('弟', 7),
#  ('擥', 7),
#  ('看', 7),
#  ('床', 7),
#  ('憂', 7),
#  ('棄', 7),
#  ('疊', 7),
#  ('試', 7),
#  ('偏', 7),
#  ('恭', 7),
#  ('饒', 7),
#  ('近', 7),
#  ('軍', 7),
#  ('屎', 7),
#  ('畢', 7),
#  ('遙', 7),
#  ('胸', 7),
#  ('融', 7),
#  ('礙', 7),
#  ('蹹', 7),
#  ('麻', 7),
#  ('築', 7),
#  ('炬', 7),
#  ('薩', 7),
#  ('片', 7),
#  ('辱', 7),
#  ('星', 7),
#  ('薄', 7),
#  ('延', 7),
#  ('奴', 7),
#  ('差', 7),
#  ('惑', 7),
#  ('甲', 7),
#  ('饉', 7),
#  ('疫', 7),
#  ('罰', 7),
#  ('童', 7),
#  ('靜', 6),
#  ('敷', 6),
#  ('哉', 6),
#  ('慢', 6),
#  ('強', 6),
#  ('攝', 6),
#  ('憍', 6),
#  ('結', 6),
#  ('壘', 6),
#  ('沼', 6),
#  ('毗', 6),
#  ('蔗', 6),
#  ('毒', 6),
#  ('階', 6),
#  ('脇', 6),
#  ('砌', 6),
#  ('歌', 6),
#  ('背', 6),
#  ('拔', 6),
#  ('恣', 6),
#  ('尋', 6),
#  ('駈', 6),
#  ('浪', 6),
#  ('稠', 6),
#  ('糩', 6),
#  ('油', 6),
#  ('全', 6),
#  ('露', 6),
#  ('齒', 6),
#  ('設', 6),
#  ('婬', 6),
#  ('愁', 6),
#  ('臂', 6),
#  ('愍', 6),
#  ('顯', 6),
#  ('精', 6),
#  ('了', 6),
#  ('貌', 6),
#  ('勤', 6),
#  ('視', 6),
#  ('違', 6),
#  ('疲', 6),
#  ('磑', 6),
#  ('劇', 6),
#  ('餓', 6),
#  ('腭', 6),
#  ('胃', 6),
#  ('豆', 6),
#  ('骸', 6),
#  ('注', 6),
#  ('震', 6),
#  ('剃', 6),
#  ('澁', 6),
#  ('羊', 6),
#  ('碎', 6),
#  ('射', 6),
#  ('刈', 6),
#  ('路', 6),
#  ('懈', 6),
#  ('競', 6),
#  ('蠟', 6),
#  ('宜', 6),
#  ('禁', 6),
#  ('候', 6),
#  ('磧', 6),
#  ('鎧', 6),
#  ('算', 6),
#  ('堅', 6),
#  ('寐', 6),
#  ('呪', 6),
#  ('謫', 6),
#  ('聽', 5),
#  ('怠', 5),
#  ('統', 5),
#  ('許', 5),
#  ('醉', 5),
#  ('菴', 5),
#  ('辛', 5),
#  ('舞', 5),
#  ('適', 5),
#  ('雖', 5),
#  ('映', 5),
#  ('廁', 5),
#  ('瓦', 5),
#  ('接', 5),
#  ('氛', 5),
#  ('鮮', 5),
#  ('進', 5),
#  ('缺', 5),
#  ('盈', 5),
#  ('姉', 5),
#  ('妹', 5),
#  ('枯', 5),
#  ('衢', 5),
#  ('工', 5),
#  ('匠', 5),
#  ('粟', 5),
#  ...]

# %% [markdown]
# <h4>Appendix Two:</h4>

# %%
#!/bin/bash
# A (very) simple script to prepare specific CBETA files for analysis in Python
# Otto Koria - 5/Apr/2020  

#Note: the Bash shell script below is not needed in the final product as all necessary files are provided. They are here to showcase the method for acquiring said files and may be run if desired.

#create directory for files
mkdir ahanbu && mkdir CBETA-texts-original && cd CBETA-texts-original

#download relevant text file of the CBETA corpus in GitHub (*note* these files is 34.0 MB)
svn export https://github.com/cbeta-org/xml-p5/tags/CBETA2019Q4/T/T01/ && svn export https://github.com/cbeta-org/xml-p5/tags/CBETA2019Q4/T/T02/ && cd ..

#XML metadata will be removed via "TACL," a piece of software designed for performing basic text analysis on the CBETA corpus (see: "https://pythonhosted.org/tacl/").
tacl prepare CBETA-texts-original .CBETA-texts-prepared && tacl strip .CBETA-texts-prepared .CBETA-texts-stripped-renamed

#this to find all sutras 經 and rename them according to their CBETA title
cd .CBETA-texts-stripped-renamed && find . -type f -name '*.txt' -exec sh -c '
  for file; do
    if newname=$(grep -m1 "經" "$file"); then
       mv "$file" "${file%/*}/${newname}.txt";
    fi
  done
' sh {} +

#moving files to final directory
cd .. && find .CBETA-texts-stripped-renamed/ -name "*經*.txt" -exec mv {} ahanbu/ \;

#deleting any potential duplicates with fdupes (likely not needed)
cd ahanbu/ && fdupes -r -f . | grep -v '^$' | xargs rm -v

#cleaning unecessary directories
cd .. && rm -rf .*

#done message
echo "done!"
